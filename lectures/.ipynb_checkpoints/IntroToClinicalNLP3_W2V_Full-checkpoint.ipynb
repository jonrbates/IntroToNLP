# %% [markdown]
# # Introduction to Natural Language Processing
#
# In this notebook, we'll go over the Word2Vec skip-gram model.
#
# The skip-gram Word2Vec model predicts the context words from a given word.

# %%
import sys
print(sys.version)   # check python version; using 3.5 for tensorflow
# Out:
# 3.5.2 |Anaconda 4.2.0 (64-bit)| (default, Jul  5 2016, 11:41:13) [MSC v.1900 64 bit (AMD64)]

# %%
# %matplotlib inline
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
import nltk
from matplotlib import pylab
from six.moves import range
from sklearn.manifold import TSNE

# %%
from sklearn.datasets import fetch_20newsgroups
news = fetch_20newsgroups(subset='train',
                          remove=('headers', 'footers', 'quotes'))
ltokens = [nltk.word_tokenize(doc) for doc in news.data]
# convert list of list of tokens (ltokens) into a list of tokens
import itertools
words = list(itertools.chain.from_iterable(ltokens))

# %%
print(len(news.data), 'articles')
print(len(words), 'words')
# Out:
# 11314 articles
# 3013035 words

# %%
words[:20]
# Out:
# ['I',
#  'was',
#  'wondering',
#  'if',
#  'anyone',
#  'out',
#  'there',
#  'could',
#  'enlighten',
#  'me',
#  'on',
#  'this',
#  'car',
#  'I',
#  'saw',
#  'the',
#  'other',
#  'day',
#  '.',
#  'It']

# %%
collections.Counter(words).most_common(10)
# Out:
# [(',', 110575),
#  ('.', 102912),
#  ('the', 94626),
#  ('>', 83268),
#  ("'AX", 61701),
#  ('--', 61024),
#  ('to', 51790),
#  ('of', 45909),
#  ('(', 40646),
#  ('a', 40469)]

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 10000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])

# Note
#     words[i] = reverse_dictionary[data[i]])
#

del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 330341], (',', 110575), ('.', 102912), ('the', 94626), ('>', 83268)]
# Sample data [13, 48, 1271, 61, 185, 81, 69, 116, 0, 76]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['I', 'was', 'wondering', 'if', 'anyone', 'out', 'there', 'could']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['was', 'was', 'wondering', 'wondering', 'if', 'if', 'anyone', 'anyone']
#     labels: ['I', 'wondering', 'if', 'was', 'wondering', 'anyone', 'out', 'if']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['wondering', 'wondering', 'wondering', 'wondering', 'if', 'if', 'if', 'if']
#     labels: ['anyone', 'was', 'I', 'if', 'wondering', 'out', 'was', 'anyone']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 1000001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 5000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 50000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.059317
# Nearest to [: mistakes, care, ink, depends, soldiers, like, Joint, Just,
# Nearest to like: Annual, thoughts, jail, M2, Korea, Ohio, formation, PIONEER,
# Nearest to 1: classification, less, appreciated, Saturday, print, 143, resort, View,
# Nearest to on: place, medicine, transfer, Test, =0, measure, bar, reactions,
# Nearest to other: often, ___, performance, needed, YJ, G9\7, Simple, opening,
# Nearest to from: d, btw, charging, graphical, outer, recall, showed, Study,
# Nearest to ``: Ethernet, getting, Hospital, cs.uiuc.edu, experiments, installation, XUSERFILESEARCHPATH, cards,
# Nearest to for: closer, equivalent, buying, mixer, perform, heating, historically, pursuing,
# Nearest to be: committing, First, Author, regard, jumped, External, Mar, information,
# Nearest to X: flamed, Islam, very, suppress, oh, Rev, ranging, 38,
# Nearest to your: Access, Observer, imposed, Chris, continue, Visual, Dos, BTW,
# Nearest to 'AX: xwd, index, discussed, doubts, church, syndrome, GM, burn,
# Nearest to $: D.C., Murphy, die, implied, bullpen, U+, Real, QUE,
# Nearest to has: cash, 300, win, effect, expert, 0.70, straightforward, four,
# Nearest to all: who, chipset, Somehow, -34, contribute, encrypting, controlling, fraction,
# Nearest to any: lunar, o'clock, goalies, Senator, BB, Water, extermination, bullets,
# Average loss at step 5000: 8.472870
# Average loss at step 10000: 7.538286
# Average loss at step 15000: 7.394300
# Average loss at step 20000: 6.770254
# Average loss at step 25000: 7.302454
# Average loss at step 30000: 7.923602
# Average loss at step 35000: 7.524378
# Average loss at step 40000: 6.726990
# Average loss at step 45000: 7.613753
# Average loss at step 50000: 7.158013
# Nearest to [: deleted, ], Hi, ink, tables, Line, 5U, THe,
# Nearest to like: say, MB/s, *******, reconcile, 'cause, 5.0, do, wear,
# Nearest to 1: 2, 3, 4, 0, Montreal, -2, Markus, 1st,
# Nearest to on: into, upon, in, past, at, from, outside, primary,
# Nearest to other: more, Many, these, location, different, performance, two, four,
# Nearest to from: into, by, without, graphical, of, on, Robin, to,
# Nearest to ``: '', Enjoy, switched, reminded, solved, SP\, folks, rumor,
# Nearest to for: upcoming, historically, within, heating, to, With, before, at,
# Nearest to be: been, have, get, were, was, is, being, are,
# Nearest to X: cord, 24-bit, Oakland, QS/, Energy, Rev, article, *,
# Nearest to your: my, his, their, our, My, her, the, this,
# Nearest to 'AX: GIZ, KM, 7EY, diplomats, 250-, RR, ',3, W-S,
# Nearest to $: Gm, looking, impression, ESPN, Anybody, 3-D, M/S, playing,
# Nearest to has: had, have, was, is, does, 's, 've, Major,
# Nearest to all: invade, what, both, installing, sensitivity, terms, course, fraction,
# Nearest to any: some, no, anything, Any, another, several, studies, enough,
# Average loss at step 55000: 6.820726
# Average loss at step 60000: 6.845760
# Average loss at step 65000: 6.347167
# Average loss at step 70000: 6.904525
# Average loss at step 75000: 7.538121
# Average loss at step 80000: 7.169082
# Average loss at step 85000: 6.435601
# Average loss at step 90000: 7.338041
# Average loss at step 95000: 6.978277
# Average loss at step 100000: 6.646284
# Nearest to [: deleted, tables, 1:1, ], ..., Read, inform, assumes,
# Nearest to like: say, want, prefer, suggest, extend, MB/s, reconcile, condemn,
# Nearest to 1: 2, 0, 4, 3, 5, -2, 8, Montreal,
# Nearest to on: upon, into, in, outside, detailed, Additional, Food, coming,
# Nearest to other: location, Many, various, most, performance, greater, following, many,
# Nearest to from: into, by, exceeds, without, regarding, towards, in, determines,
# Nearest to ``: Enjoy, church, '', reminded, communicate, importantly, LEAGUE, neighbor,
# Nearest to for: For, upcoming, heating, With, receivers, with, within, newline,
# Nearest to be: been, were, is, become, get, being, have, refer,
# Nearest to X: cord, *, anonymous, removal, programming, obfuscated, Cause, Software,
# Nearest to your: my, his, their, our, her, My, the, Your,
# Nearest to 'AX: GIZ, RR, KM, Key, MAX, 7EY, GK, 250-,
# Nearest to $: looking, Gm, NJD, specially, safer, grown, +61, pin,
# Nearest to has: had, have, is, does, Major, 've, covers, was,
# Nearest to all: both, invade, All, course, what, best, installing, sensitivity,
# Nearest to any: some, no, Any, anything, anyone, each, several, another,
# Average loss at step 105000: 6.675262
# Average loss at step 110000: 6.208791
# Average loss at step 115000: 6.756623
# Average loss at step 120000: 7.370602
# Average loss at step 125000: 7.025084
# Average loss at step 130000: 6.293771
# Average loss at step 135000: 7.211559
# Average loss at step 140000: 6.878268
# Average loss at step 145000: 6.564930
# Average loss at step 150000: 6.575427
# Nearest to [: deleted, ], tables, assumes, 1:1, Never, Read, PUSH,
# Nearest to like: prefer, want, say, suggest, extend, reconcile, likely, Sure,
# Nearest to 1: 2, 3, 4, eg, 5, 8, -2, E145,
# Nearest to on: upon, in, coming, outside, about, from, into, containing,
# Nearest to other: Many, various, location, Other, different, performance, spiritual, four,
# Nearest to from: into, exceeds, by, in, Unless, towards, across, through,
# Nearest to ``: '', Enjoy, :, reminded, Mass, greatest, church, rejected,
# Nearest to for: For, upcoming, With, of, historically, receivers, to, upper,
# Nearest to be: been, have, get, were, remain, become, refer, was,
# Nearest to X: cord, Rev, QS/, Software, FX, open, 151, Protestants,
# Nearest to your: my, his, their, our, My, her, Your, His,
# Nearest to 'AX: GIZ, Key, MAX, RR, KM, 1D9, 'AS, 'AX=,
# Nearest to $: +61, looking, students, calls, pay, safer, Gm, takes,
# Nearest to has: had, have, is, 've, does, covers, 's, Major,
# Nearest to all: invade, both, All, everyone, what, best, age, Somehow,
# Nearest to any: some, Any, anything, no, another, anyone, each, several,
# Average loss at step 155000: 6.123725
# Average loss at step 160000: 6.680335
# Average loss at step 165000: 7.273558
# Average loss at step 170000: 6.915041
# Average loss at step 175000: 6.230108
# Average loss at step 180000: 7.129303
# Average loss at step 185000: 6.793377
# Average loss at step 190000: 6.501728
# Average loss at step 195000: 6.508229
# Average loss at step 200000: 6.073898
# Nearest to [: deleted, 1:1, inform, ink, Joint, ], DN, tables,
# Nearest to like: prefer, suggest, want, say, reconcile, likely, extend, symmetric,
# Nearest to 1: 2, 3, 0, 4, Montreal, 59, Drake, 7'2TM,
# Nearest to on: upon, in, from, containing, and, rear, regarding, On,
# Nearest to other: Other, various, Many, different, new, performance, UNIX, conversion,
# Nearest to from: into, on, exceeds, by, via, graphical, towards, across,
# Nearest to ``: '', Enjoy, Mass, NRA, Sources, ie, presenting, Lightning,
# Nearest to for: For, With, of, upcoming, macro, to, gate, heating,
# Nearest to be: been, have, were, is, become, was, remain, get,
# Nearest to X: cord, also, cc, xterm, obfuscated, retain, calculate, domain,
# Nearest to your: my, his, their, My, Your, our, her, His,
# Nearest to 'AX: GIZ, MAX, Key, RR, 'AS, WWIZ, 1T, 7EY,
# Nearest to $: 1/2, +61, Gm, NJD, takes, Cape, Microdistrict, safer,
# Nearest to has: had, have, is, 's, does, covers, 've, ISBN,
# Nearest to all: both, invade, All, Lyme, shipping, everyone, installing, Eddie,
# Nearest to any: some, Any, no, each, anything, anyone, several, another,
# Average loss at step 205000: 6.613108
# Average loss at step 210000: 7.205890
# Average loss at step 215000: 6.814962
# Average loss at step 220000: 6.207324
# Average loss at step 225000: 7.062449
# Average loss at step 230000: 6.757359
# Average loss at step 235000: 6.449351
# Average loss at step 240000: 6.458022
# Average loss at step 245000: 6.035895
# Average loss at step 250000: 6.566848
# Nearest to [: ], deleted, Read, THe, ..., inform, reconcile, ^^^^^^^^^,
# Nearest to like: prefer, suggest, say, want, reconcile, unlikely, imagine, think,
# Nearest to 1: 2, 0, 3, 4, 16, eg, 5, M6,
# Nearest to on: upon, in, On, nearby, damaged, ordering, seeking, corpses,
# Nearest to other: Other, various, others, conversion, Many, historical, different, Encyclopedia,
# Nearest to from: exceeds, into, through, towards, by, Unless, determines, respects,
# Nearest to ``: '', Enjoy, liar, docs, Mass, unlawful, Q, unto,
# Nearest to for: For, of, upcoming, at, gate, assert, upper, if,
# Nearest to be: been, have, were, get, is, was, remain, refer,
# Nearest to X: cord, idle, MSDOS, install, TCP/IP, Protestants, extensions, domain,
# Nearest to your: my, his, their, our, her, Your, His, My,
# Nearest to 'AX: MAX, GIZ, Key, JB, 1D9, 1T, 'AS, WWIZ,
# Nearest to $: safer, takes, MHz, M/S, pressing, pts, +61, 3.3,
# Nearest to has: had, have, is, does, 've, magnetic, covers, contributed,
# Nearest to all: both, invade, All, installing, everyone, funding, skin, what,
# Nearest to any: some, Any, no, several, anything, anyone, another, each,
# Average loss at step 255000: 7.144060
# Average loss at step 260000: 6.735022
# Average loss at step 265000: 6.205747
# Average loss at step 270000: 7.015757
# Average loss at step 275000: 6.717088
# Average loss at step 280000: 6.414671
# Average loss at step 285000: 6.421752
# Average loss at step 290000: 5.998257
# Average loss at step 295000: 6.530914
# Average loss at step 300000: 7.109807
# Nearest to [: ], (, ), sub, Allen, Mar, gld, Call,
# Nearest to like: prefer, suggest, say, want, unlikely, reconcile, paranoid, suspect,
# Nearest to 1: 2, 3, 0, 4, X^-, 8, 5, E145,
# Nearest to on: upon, in, over, seeking, corpses, about, On, damaged,
# Nearest to other: Other, various, historical, conversion, alternative, others, different, contradictory,
# Nearest to from: into, exceeds, by, through, graphical, mice, respects, with,
# Nearest to ``: '', Q, Enjoy, liar, ie, docs, Mass, Mother,
# Nearest to for: For, With, at, if, with, macro, heating, makes,
# Nearest to be: been, have, get, were, become, remain, stop, was,
# Nearest to X: cord, TCP/IP, idle, xterm, X11, developers, domain, MSDOS,
# Nearest to your: my, his, their, our, the, Your, His, My,
# Nearest to 'AX: MAX, GIZ, JB, 1T, 1D9, 'AS, 'AX=, WT,
# Nearest to $: Molecular, safer, 109, Used, wagon, km, 1/2, feet,
# Nearest to has: had, have, is, was, 've, does, covers, requires,
# Nearest to all: both, All, invade, everybody, adapted, installing, everyone, what,
# Nearest to any: some, Any, no, anyone, anything, several, anybody, each,
# Average loss at step 305000: 6.663181
# Average loss at step 310000: 6.205906
# Average loss at step 315000: 6.980370
# Average loss at step 320000: 6.687934
# Average loss at step 325000: 6.382154
# Average loss at step 330000: 6.386161
# Average loss at step 335000: 5.986743
# Average loss at step 340000: 6.500165
# Average loss at step 345000: 7.079688
# Average loss at step 350000: 6.591314
# Nearest to [: ], deleted, <, &, inform, 2.10, _____, >,
# Nearest to like: prefer, suggest, want, say, likely, reconcile, unlikely, suspect,
# Nearest to 1: 2, 3, 0, 4, 16, 22, SG, fprintf,
# Nearest to on: upon, in, from, On, seeking, parking, with, CCD,
# Nearest to other: Other, various, others, validity, new, volunteers, alternative, existing,
# Nearest to from: into, exceeds, through, by, regarding, on, in, scattered,
# Nearest to ``: '', Enjoy, survivors, ie, 550, things, competition, UPS,
# Nearest to for: For, With, without, onto, upcoming, macro, w/, Trident,
# Nearest to be: have, been, get, become, remain, influence, contain, were,
# Nearest to X: TCP/IP, X11, cord, developers, xterm, idle, MSDOS, IPX,
# Nearest to your: my, his, their, her, our, His, Your, My,
# Nearest to 'AX: MAX, GIZ, JB, 1T, ',3, 1QY, 'AX=, 1D9,
# Nearest to $: %, 109, 97, Molecular, 28, NJD, Used, 105,
# Nearest to has: had, have, is, was, 've, does, magnetic, covers,
# Nearest to all: All, both, invade, age, everybody, installing, Dryden, adapted,
# Nearest to any: some, Any, no, anything, anybody, anyone, several, each,
# Average loss at step 355000: 6.208281
# Average loss at step 360000: 6.956326
# Average loss at step 365000: 6.662073
# Average loss at step 370000: 6.358230
# Average loss at step 375000: 6.346808
# Average loss at step 380000: 5.968585
# Average loss at step 385000: 6.471955
# Average loss at step 390000: 7.056821
# Average loss at step 395000: 6.522655
# Average loss at step 400000: 6.224009
# Nearest to [: inform, deleted, ], Read, sub, Soon, 6.0, THe,
# Nearest to like: prefer, suggest, want, say, 'cause, screws, unlikely, suspect,
# Nearest to 1: 2, 3, 4, TQ,3, P\/3, 6, 22, Price,
# Nearest to on: upon, in, On, at, from, coming, through, destination,
# Nearest to other: Other, others, contradictory, new, alternative, various, validity, more,
# Nearest to from: into, exceeds, through, regarding, in, by, respects, graphical,
# Nearest to ``: '', Enjoy, things, reminded, liar, utter, Q, desire,
# Nearest to for: For, upcoming, in, With, respectable, after, with, if,
# Nearest to be: been, have, remain, get, become, were, are, contain,
# Nearest to X: TCP/IP, cord, developers, xterm, X11, idle, MSDOS, IPX,
# Nearest to your: my, his, their, our, My, His, her, Your,
# Nearest to 'AX: MAX, GIZ, JB, ',3, 1T, QAX, 'AX=, 1D9,
# Nearest to $: students, feet, 97, safer, qualified, 109, kg, NJD,
# Nearest to has: had, have, is, does, needs, 've, was, covers,
# Nearest to all: both, All, invade, everybody, Somehow, funding, adapted, Utica,
# Nearest to any: some, Any, no, anything, anyone, another, several, anybody,
# Average loss at step 405000: 6.914850
# Average loss at step 410000: 6.651213
# Average loss at step 415000: 6.341277
# Average loss at step 420000: 6.326481
# Average loss at step 425000: 5.924666
# Average loss at step 430000: 6.473045
# Average loss at step 435000: 7.035188
# Average loss at step 440000: 6.465162
# Average loss at step 445000: 6.243057
# Average loss at step 450000: 6.900109
# Nearest to [: ], sub, deleted, _____, Call, Read, THe, WHO,
# Nearest to like: prefer, suggest, want, unlikely, 'cause, reconcile, say, supposed,
# Nearest to 1: 2, 0, 3, -S, CGA, 4, eg, Price,
# Nearest to on: upon, in, over, confidential, into, Lunar, newsgroups, leaning,
# Nearest to other: Other, others, contradictory, various, validity, new, physical, more,
# Nearest to from: into, through, by, in, exceeds, of, nearest, graphical,
# Nearest to ``: Enjoy, '', Q, rumor, desire, reminded, disclosure, 550,
# Nearest to for: For, without, macro, by, upcoming, respectable, of, in,
# Nearest to be: been, get, have, remain, become, were, was, deliver,
# Nearest to X: *, TCP/IP, ASCII, xterm, summarize, #, 5.P, idle,
# Nearest to your: my, his, their, her, Your, our, His, My,
# Nearest to 'AX: MAX, GIZ, ',3, 1T, JB, 1D9, QAX, 'AS,
# Nearest to $: feet, %, 1/2, students, 12, +6, match, 97,
# Nearest to has: had, have, is, does, covers, needs, magnetic, 've,
# Nearest to all: both, All, everybody, invade, Somehow, reproduce, adapted, funding,
# Nearest to any: some, Any, no, anything, anyone, anybody, several, another,
# Average loss at step 455000: 6.632488
# Average loss at step 460000: 6.326741
# Average loss at step 465000: 6.313419
# Average loss at step 470000: 5.877175
# Average loss at step 475000: 6.490431
# Average loss at step 480000: 7.011493
# Average loss at step 485000: 6.412895
# Average loss at step 490000: 6.260114
# Average loss at step 495000: 6.885963
# Average loss at step 500000: 6.613384
# Nearest to [: ], _____, Mar, Dear, Read, Soon, sub, ^^^^^^^^^,
# Nearest to like: prefer, suggest, want, say, unlikely, likely, require, suspect,
# Nearest to 1: 2, 0, 3, 4, 23, Q,3`, Lots, Price,
# Nearest to on: upon, in, leaning, into, repeating, damaged, nearby, over,
# Nearest to other: Other, others, various, contradictory, libertarians, casual, more, validity,
# Nearest to from: into, through, by, exceeds, of, plaintext, with, respects,
# Nearest to ``: '', Enjoy, Q, liar, rumor, atheist, switched, Muhammad,
# Nearest to for: For, to, by, in, after, With, with, of,
# Nearest to be: been, get, have, was, were, is, 'm, remain,
# Nearest to X: ASCII, IR, FX, xterm, cc, *, X11, IPX,
# Nearest to your: my, his, their, her, our, Your, His, My,
# Nearest to 'AX: MAX, GIZ, JB, 1T, 1Q\, ',3, QAX, 1D9,
# Nearest to $: feet, students, 97, offering, %, Sale, 28, 143,
# Nearest to has: had, have, is, does, needs, tries, considers, wants,
# Nearest to all: All, both, everybody, invade, everyone, reproduce, what, Somehow,
# Nearest to any: some, Any, anything, no, anyone, zero, anybody, ANY,
# Average loss at step 505000: 6.311704
# Average loss at step 510000: 6.299788
# Average loss at step 515000: 5.830784
# Average loss at step 520000: 6.511538
# Average loss at step 525000: 6.990789
# Average loss at step 530000: 6.353466
# Average loss at step 535000: 6.284396
# Average loss at step 540000: 6.861848
# Average loss at step 545000: 6.602016
# Average loss at step 550000: 6.297787
# Nearest to [: deleted, ], ^^^^^^^^^, Soon, PHI, _____, inform, THe,
# Nearest to like: prefer, want, suggest, say, *really*, paranoid, unlikely, supposed,
# Nearest to 1: 2, 0, Q,3`, 3, Cost, 4, U1, -S,
# Nearest to on: upon, in, newsgroups, confidential, On, leaning, repeating, over,
# Nearest to other: Other, various, existing, contradictory, most, electronic, mainstream, selected,
# Nearest to from: into, through, exceeds, by, 4T-, graphical, Unless, plaintext,
# Nearest to ``: 550, '', Enjoy, liar, processor, UPS, conspiracy, desire,
# Nearest to for: For, w/, wonderful, with, without, in, 1.75, after,
# Nearest to be: been, get, have, was, is, contain, become, were,
# Nearest to X: idle, TCP/IP, *, xterm, MSDOS, ASCII, developers, open,
# Nearest to your: my, his, their, Your, her, the, My, our,
# Nearest to 'AX: MAX, JB, GIZ, 1T, 1Q\, EI:4+, EI0L+, 'AX=,
# Nearest to $: 97, Used, 143, 109, 3.3, feet, Logitech, kg,
# Nearest to has: had, have, is, does, covers, needs, tries, Has,
# Nearest to all: All, both, invade, Somehow, everybody, skin, reproduce, ALL,
# Nearest to any: some, Any, no, anything, anyone, the, ANY, anybody,
# Average loss at step 555000: 6.284536
# Average loss at step 560000: 5.774105
# Average loss at step 565000: 6.538918
# Average loss at step 570000: 6.973243
# Average loss at step 575000: 6.304922
# Average loss at step 580000: 6.308221
# Average loss at step 585000: 6.845582
# Average loss at step 590000: 6.601106
# Average loss at step 595000: 6.279863
# Average loss at step 600000: 6.275269
# Nearest to [: Read, deleted, _____, ^^^^^^^^^, THe, inform, ], Rather,
# Nearest to like: prefer, want, suggest, *really*, say, hate, supposed, require,
# Nearest to 1: 2, 3, 4, 0, 5, Xm, -S, 6,
# Nearest to on: in, upon, regarding, flat, leaning, from, of, On,
# Nearest to other: Other, various, existing, contradictory, selected, others, American, casual,
# Nearest to from: into, by, through, contacts, of, exceeds, in, welfare,
# Nearest to ``: '', 550, seeds, :, disclosure, Pretty, Enjoy, Mass,
# Nearest to for: For, of, to, in, w/, by, wonderful, upcoming,
# Nearest to be: been, get, have, were, was, become, contribute, receive,
# Nearest to X: ASCII, xterm, MSDOS, idle, ideal, TCP/IP, cc, X11,
# Nearest to your: my, his, their, her, our, Your, My, His,
# Nearest to 'AX: MAX, GIZ, 1T, 1Q\, ',3, JB, EI:4+, EI0L+,
# Nearest to $: 1/2, 3.3, students, takes, million, WAY, looking, feet,
# Nearest to has: had, have, is, needs, does, 've, 's, considers,
# Nearest to all: All, both, everybody, invade, Somehow, what, adapted, reproduce,
# Nearest to any: some, Any, ANY, no, anything, anyone, anybody, the,
# Average loss at step 605000: 5.726215
# Average loss at step 610000: 6.562893
# Average loss at step 615000: 6.967249
# Average loss at step 620000: 6.252445
# Average loss at step 625000: 6.328715
# Average loss at step 630000: 6.837558
# Average loss at step 635000: 6.588149
# Average loss at step 640000: 6.271842
# Average loss at step 645000: 6.258011
# Average loss at step 650000: 5.686765
# Nearest to [: deleted, ], THe, ^^^^^^^^^, Dear, inform, Student, Commander,
# Nearest to like: prefer, suggest, want, *really*, say, supposed, require, hate,
# Nearest to 1: 2, 3, 0, 4, Beranek, CGA, 6, Hawgood,
# Nearest to on: upon, in, regarding, thru, confidential, from, On, over,
# Nearest to other: Other, various, new, contradictory, others, selected, existing, electronic,
# Nearest to from: into, by, through, graphical, contacts, exceeds, in, via,
# Nearest to ``: '', 550, Enjoy, roots, disclosure, ie, jewish, Pretty,
# Nearest to for: For, w/, of, to, with, upcoming, includes, by,
# Nearest to be: been, have, were, get, become, constitute, was, contain,
# Nearest to X: cc, TCP/IP, developers, MSDOS, idle, programmers, xterm, shading,
# Nearest to your: my, his, their, Your, the, My, her, our,
# Nearest to 'AX: MAX, 1T, GIZ, 1Q\, WT, EI0L+, 1QY, EI:4+,
# Nearest to $: 97, %, 3.3, feet, X-Force, 1/2, takes, <,
# Nearest to has: have, had, is, needs, does, supports, 's, requires,
# Nearest to all: All, both, invade, Utica, everybody, various, Somehow, Latin,
# Nearest to any: some, Any, no, ANY, anything, anyone, each, the,
# Average loss at step 655000: 6.583759
# Average loss at step 660000: 6.949332
# Average loss at step 665000: 6.212458
# Average loss at step 670000: 6.358055
# Average loss at step 675000: 6.824962
# Average loss at step 680000: 6.573181
# Average loss at step 685000: 6.262999
# Average loss at step 690000: 6.248055
# Average loss at step 695000: 5.638507
# Average loss at step 700000: 6.610390
# Nearest to [: ], Read, ^^^^^^^^^, deleted, THe, gld, _____, inform,
# Nearest to like: prefer, suggest, want, say, *really*, supposed, unlikely, imagine,
# Nearest to 1: 2, 0, 3, 4, P\/3, Cost, Q,3`, CGA,
# Nearest to on: upon, in, regarding, On, repeating, confidential, from, over,
# Nearest to other: Other, various, others, validity, scholarly, electronic, uuencoded, casual,
# Nearest to from: into, through, by, exceeds, of, in, with, contacts,
# Nearest to ``: '', liar, Enjoy, Q, 550, Pretty, docs, Allah,
# Nearest to for: For, of, with, at, in, to, if, from,
# Nearest to be: been, get, have, were, was, contain, receive, remain,
# Nearest to X: TCP/IP, idle, MSDOS, cc, *, open, ASCII, summarize,
# Nearest to your: my, his, their, our, her, Your, His, the,
# Nearest to 'AX: MAX, 1T, 1Q\, WT, GIZ, ',3, EI0L+, QAX,
# Nearest to $: 97, 3.3, km, feet, 1/2, approximately, intended, 109,
# Nearest to has: had, have, is, needs, does, loses, requires, 've,
# Nearest to all: All, both, everybody, Somehow, invade, everything, scream, what,
# Nearest to any: some, Any, no, ANY, anyone, anything, anybody, his/her,
# Average loss at step 705000: 6.939180
# Average loss at step 710000: 6.163290
# Average loss at step 715000: 6.377280
# Average loss at step 720000: 6.805286
# Average loss at step 725000: 6.580324
# Average loss at step 730000: 6.258133
# Average loss at step 735000: 6.249523
# Average loss at step 740000: 5.592504
# Average loss at step 745000: 6.640927
# Average loss at step 750000: 6.934369
# Nearest to [: ], (, ^^^^^^^^^, 20:00, gld, _____, ****************************************************************************, Short,
# Nearest to like: prefer, suggest, want, *really*, unlikely, say, suspect, paranoid,
# Nearest to 1: 2, 3, 4, 0, P\/3, CGA, FIJ, Cost,
# Nearest to on: upon, in, into, about, with, regarding, over, miss,
# Nearest to other: Other, various, others, validity, scholarly, most, contradictory, electronic,
# Nearest to from: into, by, through, exceeds, with, respects, graphical, From,
# Nearest to ``: '', Q, docs, liar, 550, Enjoy, Pretty, Mother,
# Nearest to for: For, of, with, at, if, to, in, by,
# Nearest to be: been, have, get, were, become, receive, remain, contain,
# Nearest to X: TCP/IP, MSDOS, ASCII, idle, locks, simpler, xterm, X11,
# Nearest to your: my, his, their, our, the, her, Your, thier,
# Nearest to 'AX: MAX, 1T, 1Q\, WT, GIZ, JB, ',3, _Q\,
# Nearest to $: 3.3, 97, Looking, X-Force, 1/2, feet, million, wagon,
# Nearest to has: had, have, is, does, was, needs, Has, loses,
# Nearest to all: both, All, everybody, everything, Somehow, Utica, invade, what,
# Nearest to any: some, ANY, no, Any, anyone, anything, anybody, several,
# Average loss at step 755000: 6.118661
# Average loss at step 760000: 6.409875
# Average loss at step 765000: 6.774748
# Average loss at step 770000: 6.584979
# Average loss at step 775000: 6.250765
# Average loss at step 780000: 6.246382
# Average loss at step 785000: 5.545318
# Average loss at step 790000: 6.672728
# Average loss at step 795000: 6.927356
# Average loss at step 800000: 6.079891
# Nearest to [: ], _____, deleted, ^^^^^^^^^, inform, ?, ****************************************************************************, #,
# Nearest to like: prefer, suggest, want, *really*, imagine, say, suspect, unlikely,
# Nearest to 1: 2, 3, 0, 4, P\/3, 10, 6, /6,
# Nearest to on: upon, in, On, from, over, into, thru, with,
# Nearest to other: various, others, Other, validity, more, DL, Bosnian, scholarly,
# Nearest to from: by, into, exceeds, through, in, on, respects, without,
# Nearest to ``: Pretty, '', liar, Enjoy, 550, things, Mother, ie,
# Nearest to for: For, with, without, by, w/, of, to, 1.75,
# Nearest to be: been, have, get, become, were, contain, are, constitute,
# Nearest to X: TCP/IP, developers, IPX, ASCII, X11, MSDOS, cc, xterm,
# Nearest to your: my, his, their, our, her, Your, His, thier,
# Nearest to 'AX: MAX, 1Q\, 1T, WT, GIZ, ',3, _Q\, EI0L+,
# Nearest to $: 97, %, 3.3, &, obo, Punisher, X-Force, pts,
# Nearest to has: had, have, is, Has, was, needs, does, Having,
# Nearest to all: both, All, Somehow, everybody, funding, age, adapted, invade,
# Nearest to any: some, ANY, Any, no, anything, anyone, anybody, a,
# Average loss at step 805000: 6.424178
# Average loss at step 810000: 6.733020
# Average loss at step 815000: 6.597084
# Average loss at step 820000: 6.240592
# Average loss at step 825000: 6.234711
# Average loss at step 830000: 5.509148
# Average loss at step 835000: 6.698312
# Average loss at step 840000: 6.906469
# Average loss at step 845000: 6.088808
# Average loss at step 850000: 6.418050
# Nearest to [: ], deleted, _____, ^^^^^^^^^, inform, Much, Dear, excess,
# Nearest to like: prefer, want, say, suggest, imagine, 'cause, suspect, *really*,
# Nearest to 1: 2, 6, 3, 4, TQ,3, fprintf, Xm, .Y,
# Nearest to on: upon, in, with, into, from, regarding, for, next,
# Nearest to other: Other, others, various, validity, more, scholarly, new, related,
# Nearest to from: into, through, in, by, exceeds, for, on, respects,
# Nearest to ``: '', Enjoy, liar, Q, utter, desire, Persian, things,
# Nearest to for: For, in, with, of, at, to, from, without,
# Nearest to be: been, get, have, become, contribute, were, contain, are,
# Nearest to X: TCP/IP, IPX, X11, developers, MSDOS, cc, xterm, Windows,
# Nearest to your: my, his, their, our, the, Your, her, My,
# Nearest to 'AX: MAX, 1Q\, 1T, WT, ',3, GIZ, _Q\, EI0L+,
# Nearest to $: 97, feet, obo, X-Force, 3.3, Sale, fifty, Independence,
# Nearest to has: had, have, is, does, tries, needs, Has, loses,
# Nearest to all: All, both, everybody, Somehow, Utica, funding, BM, thereof,
# Nearest to any: some, no, Any, ANY, anything, anyone, anybody, another,
# Average loss at step 855000: 6.705336
# Average loss at step 860000: 6.606502
# Average loss at step 865000: 6.252137
# Average loss at step 870000: 6.224294
# Average loss at step 875000: 5.464215
# Average loss at step 880000: 6.730420
# Average loss at step 885000: 6.900626
# Average loss at step 890000: 6.084720
# Average loss at step 895000: 6.401531
# Average loss at step 900000: 6.673605
# Nearest to [: ], _____, ;, ^^^^^^^^^, Dear, (, ?, sub,
# Nearest to like: prefer, want, suggest, *really*, supposed, 'cause, unlikely, imagine,
# Nearest to 1: 2, 3, 0, -S, Xm, -/, /6, Z.I,
# Nearest to on: upon, in, into, over, regarding, leaning, against, with,
# Nearest to other: Other, others, various, validity, contradictory, related, electronic, sharing,
# Nearest to from: into, in, through, by, of, contacts, exceeds, for,
# Nearest to ``: '', Enjoy, Persian, Q, liar, Pretty, 550, NRA,
# Nearest to for: For, of, without, with, in, by, to, 1.75,
# Nearest to be: been, get, have, contribute, achieve, deliver, contain, was,
# Nearest to X: TCP/IP, *, cc, *output, summarize, IPX, 5.P, shading,
# Nearest to your: my, his, their, our, her, Your, His, My,
# Nearest to 'AX: MAX, 1Q\, 1T, WT, _Q\, GIZ, EI0L+, 1QY,
# Nearest to $: %, 97, <, feet, &, km, 3.3, >,
# Nearest to has: had, have, is, does, needs, requires, Has, performs,
# Nearest to all: All, both, everybody, ALL, Somehow, reproduce, Utica, funding,
# Nearest to any: some, Any, no, anything, anyone, ANY, anybody, several,
# Average loss at step 905000: 6.622538
# Average loss at step 910000: 6.254693
# Average loss at step 915000: 6.217810
# Average loss at step 920000: 5.425687
# Average loss at step 925000: 6.757639
# Average loss at step 930000: 6.892547
# Average loss at step 935000: 6.080073
# Average loss at step 940000: 6.396409
# Average loss at step 945000: 6.641731
# Average loss at step 950000: 6.647571
# Nearest to [: ], _____, ^^^^^^^^^, Dear, Royal, ****************************************************************************, Cor, Any,
# Nearest to like: want, prefer, *really*, unlikely, suggest, hate, suspect, supposed,
# Nearest to 1: 2, 0, 3, 4, Xm, 23, -/, 6,
# Nearest to on: upon, in, into, at, from, leaning, confidential, over,
# Nearest to other: Other, various, others, more, scholarly, validity, 80, contradictory,
# Nearest to from: into, by, through, exceeds, for, in, with, of,
# Nearest to ``: '', Q, liar, Mother, Koran, Enjoy, disclosure, SE/30,
# Nearest to for: For, of, by, with, from, in, to, after,
# Nearest to be: been, have, get, was, were, contribute, contain, become,
# Nearest to X: TCP/IP, cc, xterm, X11, ASCII, *output, ANSI, IPX,
# Nearest to your: my, his, their, our, her, Your, the, His,
# Nearest to 'AX: MAX, 1Q\, 1T, _Q\, WT, GIZ, EI0L+, ',3,
# Nearest to $: %, 97, feet, 102, 3.3, 0.333, degrees, +6,
# Nearest to has: had, have, is, does, needs, tries, requires, loses,
# Nearest to all: All, both, everybody, reproduce, Somehow, everything, funding, Utica,
# Nearest to any: some, Any, anyone, no, ANY, anything, anybody, zero,
# Average loss at step 955000: 6.239070
# Average loss at step 960000: 6.212994
# Average loss at step 965000: 5.383324
# Average loss at step 970000: 6.779450
# Average loss at step 975000: 6.898704
# Average loss at step 980000: 6.071158
# Average loss at step 985000: 6.387814
# Average loss at step 990000: 6.612068
# Average loss at step 995000: 6.668926
# Average loss at step 1000000: 6.236773
# Nearest to [: ], ^^^^^^^^^, _____, Dear, deleted, Wayne, Regards, anecdotal,
# Nearest to like: want, prefer, *really*, hate, suggest, suspect, supposed, imagine,
# Nearest to 1: 2, 0, 3, -S, 23, 4, Xm, Ranford,
# Nearest to on: upon, in, regarding, with, for, _is_, into, confidential,
# Nearest to other: Other, various, others, most, 80, scholarly, existing, new,
# Nearest to from: into, through, by, for, exceeds, 4T-, in, contacts,
# Nearest to ``: 550, Koran, '', Pretty, disclosure, seeds, Enjoy, Mother,
# Nearest to for: For, with, without, by, in, from, to, at,
# Nearest to be: been, get, have, were, become, is, contribute, was,
# Nearest to X: TCP/IP, *, executable, MSDOS, simpler, idle, cc, summarize,
# Nearest to your: my, his, their, our, the, Your, her, My,
# Nearest to 'AX: 1Q\, MAX, 1T, _Q\, WT, EI0L+, EI:4+, _+,
# Nearest to $: 97, feet, 102, km, %, W0, 3.3, match,
# Nearest to has: had, have, is, does, needs, supports, loses, Has,
# Nearest to all: All, both, Somehow, everybody, reproduce, Utica, *all*, ALL,
# Nearest to any: some, Any, no, anything, ANY, anyone, anybody, the,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
